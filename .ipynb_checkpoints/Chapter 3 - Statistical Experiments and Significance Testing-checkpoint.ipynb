# %% [markdown]
# ## A/B Testing

# %%
import matplotlib.pylab as plt
import numpy as np
from pathlib import Path
import pandas as pd
import math
import random as rd
import seaborn as sns
import scipy.stats as ss

# %%
DATA = Path('.').resolve() / 'data'
data = pd.read_csv(DATA / 'data-testing.csv')

# %%
data.head(10)
# Out:
#    hari  konversi_a  konversi_b
# 0     1        0.15        0.19
# 1     2        0.12        0.20
# 2     3        0.18        0.18
# 3     4        0.19        0.22
# 4     5        0.17        0.19
# 5     6        0.13        0.17
# 6     7        0.14        0.18
# 7     8        0.23        0.20
# 8     9        0.11        0.17
# 9    10        0.15        0.22

# %% [markdown]
# ### Control Sample

# %%
# print(data.Konversi_A)
plt.plot(data.hari, data.konversi_a)

# %%
sns.distplot(data.konversi_a)

# %% [markdown]
# ### Variation Sample

# %%
plt.plot(data.hari, data.konversi_b)

# %%
sns.distplot(data.konversi_b)
